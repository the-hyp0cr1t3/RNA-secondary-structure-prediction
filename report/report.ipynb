# %%
seq = "GGCGAAGAACCGGGGAGCC"
ans = [(1, 19), (2, 18), (3, 12), (4, 10)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")
sns.set_context("talk")
sns.set_palette("magma")

# %%
from matplotlib.patches import Rectangle

plt.gca().add_patch(Rectangle((1, 1), 2, 6))
plt.show()

# %%
fig, ax = plt.subplots()

#create simple line plot
# ax.plot([0, 10],[0, 10])

#add rectangle to plot
# a = ax.add_patch(Rectangle((0, 1), 2, 6, linewidth=1, edgecolor='r', facecolor='none'))
# ax.set_xlim(0, 10)
# ax.set_ylim(0, 10)

# #display plot
# plt.show()
seq = "GGC"
y = [0]*len(seq)
x = [2*x for x in range(1, len(seq)+1)]
plt.scatter(x, y)
# plt.gca().set_xticks(x)
# plt.gca().set_xticklabels(list(seq))
for i, c in enumerate(seq):
    plt.text(x[i]-0.65, -0.01, c, fontdict={"fontsize": 15})
# plt.axis('off')
